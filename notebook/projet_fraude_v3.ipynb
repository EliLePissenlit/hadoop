# %% [markdown]
# # Détection fraude bancaire
#
# HDFS : localhost:9000
# PaySim (transactions mobile money synthétiques & anonymisées
# Random Forest
#
# `start-dfs.sh` et `start-yarn.sh`
# hdfs://localhost:9000/data/raw/fraud.csv
#
# ---
#
# ## Problematique : peut-on faire mieux que la banque ?
#
# La banque possède un système anti-fraude (`isFlaggedFraud`)
# => est-il efficace, et peut-on faire mieux ?

# %% [markdown]
# ## Réglage

# %%
MODE_TEST = False   # True = petite partie du csv pour test 
TAILLE_ECHANTILLON = 0.05   # 5%

# %% [markdown]
# ## Démarrage de Spark

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import matplotlib.pyplot as plt

spark = SparkSession.builder \
    .appName("DetectionFraude") \
    .getOrCreate()

print(spark.version)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/07/21 22:17:37 WARN Utils: Your hostname, PortabledeNey, resolves to a loopback address: 127.0.1.1; using 172.29.180.170 instead (on interface eth0)
# 26/07/21 22:17:37 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/21 22:17:40 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 4.1.2

# %% [markdown]
# ## 1. Importation dataset depuis HDFS

# %%
CHEMIN_HDFS = "hdfs://localhost:9000/data/raw/fraud.csv"

df = spark.read.csv(CHEMIN_HDFS, header=True, inferSchema=True)

if MODE_TEST:
    df = df.sample(fraction=TAILLE_ECHANTILLON, seed=67)
    print(f" {TAILLE_ECHANTILLON*100:.0f}% des donnees")
else:
    print("tout")
# Out:
# [Stage 1:===>                                                     (1 + 15) / 16]
# tout

# %% [markdown]
# ## 2. Parsing

# %%
df.show(5)
# Out:
# +----+--------+--------+-----------+-------------+--------------+-----------+--------------+--------------+-------+--------------+
# |step|    type|  amount|   nameOrig|oldbalanceOrg|newbalanceOrig|   nameDest|oldbalanceDest|newbalanceDest|isFraud|isFlaggedFraud|
# +----+--------+--------+-----------+-------------+--------------+-----------+--------------+--------------+-------+--------------+
# |   1| PAYMENT| 9839.64|C1231006815|     170136.0|     160296.36|M1979787155|           0.0|           0.0|      0|             0|
# |   1| PAYMENT| 1864.28|C1666544295|      21249.0|      19384.72|M2044282225|           0.0|           0.0|      0|             0|
# |   1|TRANSFER|   181.0|C1305486145|        181.0|           0.0| C553264065|           0.0|           0.0|      1|             0|
# |   1|CASH_OUT|   181.0| C840083671|        181.0|           0.0|  C38997010|       21182.0|           0.0|      1|             0|
# |   1| PAYMENT|11668.14|C2048537720|      41554.0|      29885.86|M1230701703|           0.0|           0.0|      0|             0|
# +----+--------+--------+-----------+-------------+--------------+-----------+--------------+--------------+-------+--------------+
# only showing top 5 rows

# %%
print("colonnes & types :")
df.printSchema()
# Out:
# colonnes & types :
# root
#  |-- step: integer (nullable = true)
#  |-- type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- nameOrig: string (nullable = true)
#  |-- oldbalanceOrg: double (nullable = true)
#  |-- newbalanceOrig: double (nullable = true)
#  |-- nameDest: string (nullable = true)
#  |-- oldbalanceDest: double (nullable = true)
#  |-- newbalanceDest: double (nullable = true)
#  |-- isFraud: integer (nullable = true)
#  |-- isFlaggedFraud: integer (nullable = true)

# %%
#nb lignes 
print(df.count())
# Out:
# 6362620

# %% [markdown]
# ---
# # 1 systeme de la banque ?
#
# La colonne `isFlaggedFraud` est le système d'alerte de la banque.
# Sa règle : lever une alerte si un transfert dépasse 200 000
#
#  on test: On croise ce qu'il a signalé (`isFlaggedFraud`)
# avec la vraie fraude (`isFraud`).

# %%
df.groupBy("isFraud", "isFlaggedFraud").count().orderBy("isFraud", "isFlaggedFraud").show()
# Out:
# [Stage 6:>                                                        (0 + 16) / 16]
# +-------+--------------+-------+
# |isFraud|isFlaggedFraud|  count|
# +-------+--------------+-------+
# |      0|             0|6354407|
# |      1|             0|   8197|
# |      1|             1|     16|
# +-------+--------------+-------+

# %%
# on compte les fraudes detectees et ratees par le systeme de la banque
fraudes_oui = df.filter((df.isFraud == 1) & (df.isFlaggedFraud == 1)).count()
fraudes_non = df.filter((df.isFraud == 1) & (df.isFlaggedFraud == 0)).count()
totalF = fraudes_oui + fraudes_non

print("f detectees banque :", fraudes_oui)
print("f ratees banque    :", fraudes_non)
print("total f            :", totalF)
print("taux de detection  :", round(100 * fraudes_oui / totalF, 2), "%")
# Out:
# [Stage 12:>                                                       (0 + 16) / 16]
# f detectees banque : 16
# f ratees banque    : 8197
# total f            : 8213
# taux de detection  : 0.19 %

# %%
plt.figure(figsize=(6, 4))
plt.bar(["ratees", "detectees"], [fraudes_non, fraudes_oui], color=["red", "green"])
plt.title("fraudes vues par le systeme de la banque")
plt.ylabel("nb fraudes")
plt.show()

# %% [markdown]
# ### Conclusion
#
# Le système de la banque ne détecte quasiment rien
#
#
# C'est notre point de départ et notre référence à battre
# On peut donc supprimer cette colonne : elle n'apporte aucune information utile.

# %% [markdown]
# ---
# # 2 sur quels colonnes peut-on se baser

# %% [markdown]
# ### combien de fraudes?

# %%
repartition = df.groupBy("isFraud").count()
repartition.show()
# Out:
# [Stage 15:===>                                                    (1 + 15) / 16]
# +-------+-------+
# |isFraud|  count|
# +-------+-------+
# |      1|   8213|
# |      0|6354407|
# +-------+-------+

# %%
nb_fraude = df.filter(df.isFraud == 1).count()
nb_normal = df.filter(df.isFraud == 0).count()

plt.figure(figsize=(6, 4))
plt.bar(["Normal", "Fraude"], [nb_normal, nb_fraude], color=["blue", "red"])
plt.title("repartition  transactions")
plt.ylabel("nombre")
plt.show()

print("pourcentage de fraude :", round(100 * nb_fraude / (nb_fraude + nb_normal), 3), "%")
# Out:
# pourcentage de fraude : 0.129 %

# %% [markdown]
# =>Le dataset est très déséquilibré

# %% [markdown]
# ### Type de transaction

# %%
print("fraude /type de transaction :")
df.groupBy("type", "isFraud").count().orderBy("type").show()
# Out:
# fraude /type de transaction :
# [Stage 24:==========================================>             (12 + 4) / 16]
# +--------+-------+-------+
# |    type|isFraud|  count|
# +--------+-------+-------+
# | CASH_IN|      0|1399284|
# |CASH_OUT|      0|2233384|
# |CASH_OUT|      1|   4116|
# |   DEBIT|      0|  41432|
# | PAYMENT|      0|2151495|
# |TRANSFER|      1|   4097|
# |TRANSFER|      0| 528812|
# +--------+-------+-------+

# %%
# on veut fraudes / types 
fraudes_par_type = df.filter(df.isFraud == 1).groupBy("type").count()
fraudes_par_type.show()

# panda pour resultats petits 
data = fraudes_par_type.toPandas()

plt.figure(figsize=(7, 4))
plt.bar(data["type"], data["count"], color="red")
plt.title("nb fraudes/ type transaction")
plt.ylabel("nb fraudes")
plt.show()
# Out:
# +--------+-----+
# |    type|count|
# +--------+-----+
# |TRANSFER| 4097|
# |CASH_OUT| 4116|
# +--------+-----+

# %% [markdown]
# =>que sur TRANSFER et CASH_OUT
# Jamais sur PAYMENT, DEBIT, CASH_IN
# => fraudeur transfère l'argent volé puis le retire

# %% [markdown]
# ### Entre qui? (particulier/commerçant)
#
#  id de comptes commencent  par
# **C** = client / particulier
# **M** = merchant / commerce
#
# on veut de qui à qui : (CC ouCM...) et on s'en fiche des chiffres apres

# %%
df = df.withColumn(
    "typeEchange",
    F.concat(F.substring("nameOrig", 1, 1), F.substring("nameDest", 1, 1))
)

print("fraude / type d'echange (CC, CM...) :")
df.groupBy("typeEchange", "isFraud").count().orderBy("typeEchange").show()
# Out:
# fraude / type d'echange (CC, CM...) :
# [Stage 33:>                                                       (0 + 16) / 16]
# +-----------+-------+-------+
# |typeEchange|isFraud|  count|
# +-----------+-------+-------+
# |         CC|      0|4202912|
# |         CC|      1|   8213|
# |         CM|      0|2151495|
# +-----------+-------+-------+

# %%
fraudes_par_echange = df.filter(df.isFraud == 1).groupBy("typeEchange").count()
data = fraudes_par_echange.toPandas()

plt.figure(figsize=(6, 4))
plt.bar(data["typeEchange"], data["count"], color="red")
plt.title("nb fraudes / type d'echange")
plt.ylabel("nb fraudes")
plt.show()

# %% [markdown]
# => fraudes sont de type CC
# Aucune fraude vers un commerçant.

# %% [markdown]
# ### Les montants

# %%
df.select("amount").describe().show()
# Out:
# [Stage 39:===>                                                    (1 + 15) / 16]
# +-------+------------------+
# |summary|            amount|
# +-------+------------------+
# |  count|           6362620|
# |   mean|179861.90354913156|
# | stddev| 603858.2314629381|
# |    min|               0.0|
# |    max|     9.244551664E7|
# +-------+------------------+

# %%
# montant moy. fraudes / non fraudes
moy_fraude = df.filter(df.isFraud == 1).agg(F.avg("amount")).collect()[0][0]
moy_non_fraude = df.filter(df.isFraud == 0).agg(F.avg("amount")).collect()[0][0]

print("montant moy fraude     :", round(moy_fraude, 2))
print("montant moy non fraude :", round(moy_non_fraude, 2))

plt.figure(figsize=(6, 4))
plt.bar(["normal", "fraude"], [moy_non_fraude, moy_fraude], color=["blue", "red"])
plt.title("montant moyen d'une transaction")
plt.ylabel("montant moyen")
plt.show()
# Out:
# montant moy fraude     : 1467967.3
# montant moy non fraude : 178197.04

# %% [markdown]
# => fraudes portent en moyenne sur des montants plus élevés
#
#
# ### Bilan :
#
#
#
# 1  dataset déséquilibré
# 2  uniquement sur TRANSFER et CASH_OUT
# 3  uniquement entre particuliers (CC)
# 4  Montants plus élevés

# %% [markdown]
# ---
# ## Nettoyage

# %%
# doublons
df = df.dropDuplicates()

# %%
# on vire :
#  id de compte (nameOrig / nameDest) 
#  isFlaggedFraud : l'ancien systeme banque
df = df.select(
    "step", "type", "amount",
    "oldbalanceOrg", "newbalanceOrig",
    "oldbalanceDest", "newbalanceDest",
    "typeEchange", "isFraud"
)

# %%
# si col isFraud vite on vire 
df = df.dropna(subset=["isFraud"])

# %% [markdown]
# ---
# # 3 : Premier RF
#
#
# MLlib a besoin de variables numériques rassemblées dans une colonne(features) :
# - StringIndexer : texte ("PAYMENT", "CC"...) = nombres
# - vectorAssembler: rassemble les colonnes = 1 vecteur
# - RandomForestClassifier: le modèle (des arbres qui votent)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, VectorAssembler
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# %%
# colonnes txt -> nb
indexeur_type = StringIndexer(inputCol="type", outputCol="type_num")
indexeur_echange = StringIndexer(inputCol="typeEchange", outputCol="typeEchange_num")

# %%
#  colonnes pour predire 
col_avec_soldes = [
    "step", "type_num", "amount",
    "oldbalanceOrg", "newbalanceOrig",
    "oldbalanceDest", "newbalanceDest",
    "typeEchange_num"
]
assembleur_1 = VectorAssembler(inputCols=col_avec_soldes, outputCol="features")

# %%
# 50 ab decision
modele_rf_1 = RandomForestClassifier(
    featuresCol="features",
    labelCol="isFraud",
    numTrees=50
)

pipeline_1 = Pipeline(stages=[indexeur_type, indexeur_echange, assembleur_1, modele_rf_1])

# %%
# sep 80/20
train, test = df.randomSplit([0.8, 0.2], seed=67)

# %%
modele_1 = pipeline_1.fit(train)
# Out:
# 26/07/21 22:20:04 WARN MemoryStore: Not enough space to cache rdd_188_15 in memory! (computed 11.7 MiB so far)
# 26/07/21 22:20:04 WARN MemoryStore: Not enough space to cache rdd_188_5 in memory! (computed 11.7 MiB so far)
# 26/07/21 22:20:04 WARN MemoryStore: Not enough space to cache rdd_188_2 in memory! (computed 27.1 MiB so far)
# 26/07/21 22:20:04 WARN BlockManager: Persisting block rdd_188_15 to disk instead.
# 26/07/21 22:20:04 WARN BlockManager: Persisting block rdd_188_2 to disk instead.
# 26/07/21 22:20:04 WARN BlockManager: Persisting block rdd_188_5 to disk instead.
# 26/07/21 22:20:04 WARN MemoryStore: Not enough space to cache rdd_188_12 in memory! (computed 27.1 MiB so far)
# 26/07/21 22:20:04 WARN BlockManager: Persisting block rdd_188_12 to disk instead.
# 26/07/21 22:20:04 WARN MemoryStore: Not enough space to cache rdd_188_9 in memory! (computed 3.4 MiB so far)
# 26/07/21 22:20:04 WARN BlockManager: Persisting block rdd_188_9 to disk instead.
# 26/07/21 22:20:05 WARN MemoryStore: Not enough space to cache rdd_188_10 in memory! (computed 27.1 MiB so far)
# 26/07/21 22:20:05 WARN BlockManager: Persisting block rdd_188_10 to disk instead.
# 26/07/21 22:20:05 WARN MemoryStore: Not enough space to cache rdd_188_7 in memory! (computed 27.1 MiB so far)
# 26/07/21 22:20:05 WARN BlockManager: Persisting block rdd_188_7 to disk instead.
# 26/07/21 22:20:05 WARN MemoryStore: Not enough space to cache rdd_188_3 in memory! (computed 27.1 MiB so far)
# 26/07/21 22:20:05 WARN BlockManager: Persisting block rdd_188_3 to disk instead.
# 26/07/21 22:20:05 WARN MemoryStore: Not enough space to cache rdd_188_11 in memory! (computed 27.1 MiB so far)
# 26/07/21 22:20:05 WARN BlockManager: Persisting block rdd_188_11 to disk instead.
# 26/07/21 22:20:06 WARN MemoryStore: Not enough space to cache rdd_188_0 in memory! (computed 27.1 MiB so far)
# 26/07/21 22:20:06 WARN BlockManager: Persisting block rdd_188_0 to disk instead.
# 26/07/21 22:20:06 WARN MemoryStore: Not enough space to cache rdd_188_1 in memory! (computed 40.7 MiB so far)
# 26/07/21 22:20:06 WARN BlockManager: Persisting block rdd_188_1 to disk instead.
# 26/07/21 22:20:06 WARN MemoryStore: Not enough space to cache rdd_188_8 in memory! (computed 40.7 MiB so far)
# 26/07/21 22:20:06 WARN BlockManager: Persisting block rdd_188_8 to disk instead.
# 26/07/21 22:20:08 WARN MemoryStore: Not enough space to cache rdd_188_13 in memory! (computed 61.1 MiB so far)
# 26/07/21 22:20:08 WARN BlockManager: Persisting block rdd_188_13 to disk instead.
# 26/07/21 22:20:09 WARN MemoryStore: Not enough space to cache rdd_188_4 in memory! (computed 92.2 MiB so far)
# 26/07/21 22:20:09 WARN BlockManager: Persisting block rdd_188_4 to disk instead.
# 26/07/21 22:20:09 WARN MemoryStore: Not enough space to cache rdd_188_14 in memory! (computed 92.2 MiB so far)
# 26/07/21 22:20:09 WARN BlockManager: Persisting block rdd_188_14 to disk instead.
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_8 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_2 in memory! (computed 11.7 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_12 in memory! (computed 40.7 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_15 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_13 in memory! (computed 17.6 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_1 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_4 in memory! (computed 27.1 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_7 in memory! (computed 40.7 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_3 in memory! (computed 40.7 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_14 in memory! (computed 61.1 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_10 in memory! (computed 61.1 MiB so far)
# 26/07/21 22:20:12 WARN MemoryStore: Not enough space to cache rdd_188_11 in memory! (computed 3.4 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_4 in memory! (computed 2.3 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_14 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_3 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_2 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_15 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_10 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_6 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_7 in memory! (computed 3.4 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_1 in memory! (computed 3.4 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_11 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_12 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_13 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:20 WARN MemoryStore: Not enough space to cache rdd_188_8 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_2 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_15 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_10 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_4 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_11 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_7 in memory! (computed 3.4 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_14 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_8 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_13 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_3 in memory! (computed 3.4 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_12 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_6 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:24 WARN MemoryStore: Not enough space to cache rdd_188_1 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_4 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_11 in memory! (computed 1028.2 KiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_12 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_6 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_2 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_14 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_8 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_15 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_10 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_7 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_13 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_1 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:30 WARN MemoryStore: Not enough space to cache rdd_188_3 in memory! (computed 3.4 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_1 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_15 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_12 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_3 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_13 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_2 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_7 in memory! (computed 5.1 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_6 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_8 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_11 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_4 in memory! (computed 7.7 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_14 in memory! (computed 3.4 MiB so far)
# 26/07/21 22:20:37 WARN MemoryStore: Not enough space to cache rdd_188_10 in memory! (computed 7.7 MiB so far)
# [Stage 99:=================================================>      (14 + 2) / 16]

# %%
predictions_1 = modele_1.transform(test)
print("ex pred")
predictions_1.select("isFraud", "prediction", "probability").show(10)
# Out:
# ex pred
# [Stage 102:>                                                        (0 + 1) / 1]
# +-------+----------+--------------------+
# |isFraud|prediction|         probability|
# +-------+----------+--------------------+
# |      0|       0.0|[0.99954734613019...|
# |      0|       0.0|[0.99954734613019...|
# |      0|       0.0|[0.99954734613019...|
# |      0|       0.0|[0.99954734613019...|
# |      0|       0.0|[0.99954734613019...|
# |      0|       0.0|[0.99954734613019...|
# |      0|       0.0|[0.99954734613019...|
# |      0|       0.0|[0.99954734613019...|
# |      0|       0.0|[0.99930373627431...|
# |      0|       0.0|[0.99930373627431...|
# +-------+----------+--------------------+
# only showing top 10 rows

# %% [markdown]
# ### Éval modele 1

# %%
def evaluer(predictions, nom):
    # rappel pour le auc 1.0 = (trop) parfait, 0.5 = hasard
    evaluateur = BinaryClassificationEvaluator(
        labelCol="isFraud", rawPredictionCol="rawPrediction", metricName="areaUnderROC"
    )
    auc = evaluateur.evaluate(predictions)

    # les cas de la matrice de confusion
    vp = predictions.filter((predictions.isFraud == 1) & (predictions.prediction == 1)).count()  # vrais positifs
    fn = predictions.filter((predictions.isFraud == 1) & (predictions.prediction == 0)).count()  # faux negatifs
    fp = predictions.filter((predictions.isFraud == 0) & (predictions.prediction == 1)).count()  # faux positifs

    # recall = parmi les vraies fraudes, combien on en attrape
    recall = vp / (vp + fn)

    print(nom)
    print("AUC       :", round(auc, 4))
    print("detectees :", vp)
    print("ratees    :", fn)
    print("erreurs   :", fp)
    print("recall    :", round(100 * recall, 1), "%")

    return auc, recall, vp, fn, fp

# %%
auc_1, recall_1, vp_1, fn_1, fp_1 = evaluer(predictions_1, "modele 1 (avec soldes)")
# Out:
# [Stage 133:===================================================>   (16 + 1) / 17]
# modele 1 (avec soldes)
# AUC       : 0.989
# detectees : 804
# ratees    : 875
# erreurs   : 0
# recall    : 47.9 %

# %%
# matrice confusion
predictions_1.groupBy("isFraud", "prediction").count().orderBy("isFraud", "prediction").show()
# Out:
# [Stage 139:===================================================>   (16 + 1) / 17]
# +-------+----------+-------+
# |isFraud|prediction|  count|
# +-------+----------+-------+
# |      0|       0.0|1271432|
# |      1|       0.0|    875|
# |      1|       1.0|    804|
# +-------+----------+-------+

# %% [markdown]
# ### sur quelles colonnes le modele se base?

# %%
rf_1 = modele_1.stages[-1]
imp_1 = rf_1.featureImportances

for nom, score in zip(col_avec_soldes, imp_1):
    print(nom, ":", round(float(score), 4))
# Out:
# step : 0.0875
# type_num : 0.0798
# amount : 0.0553
# oldbalanceOrg : 0.3002
# newbalanceOrig : 0.0445
# oldbalanceDest : 0.0453
# newbalanceDest : 0.3871
# typeEchange_num : 0.0001

# %%
# graph importances
noms = []
vals = []
for i in range(len(col_avec_soldes)):
    noms.append(col_avec_soldes[i])
    vals.append(float(imp_1[i]))

plt.figure(figsize=(8, 5))
plt.barh(noms, vals, color="pink")
plt.title("modele 1 : importance des variables")
plt.xlabel("importance")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Probleme : le modele triche
#
# AUC 0.98 = trop elever alors que loupe bcp de fraudes
#
# doc du dataset :
# > *« NOTE: Transactions which are detected as fraud are cancelled, so for fraud
# > detection these columns (oldbalanceOrg, newbalanceOrig, oldbalanceDest,
# > newbalanceDest) must not be used. »*
#
# => les fraudes sont annulees donc les soldes sont modifies APRES coup
# => ces 4 colonnes ne doivent pas etre utilisees
#  le modele se base trop sur oldbalanceOrg + newbalanceDest
#
# ### fuite de donnees
#
# le modele apprend une consequence de la fraude, pas la fraude
#
# => on refait sans ces colonnes

# %% [markdown]
# ---
# # 4 : RF sans les soldes
#
# meme chose mais sans les 4 colonnes de soldes
# => le modele a que ce qu'on sait AU MOMENT de la transaction

# %%
#  colonnes pour predire (sans soldes)
col_sans_soldes = ["step", "type_num", "amount", "typeEchange_num"]
assembleur_2 = VectorAssembler(inputCols=col_sans_soldes, outputCol="features")

# %%
modele_rf_2 = RandomForestClassifier(
    featuresCol="features",
    labelCol="isFraud",
    numTrees=50
)

pipeline_2 = Pipeline(stages=[indexeur_type, indexeur_echange, assembleur_2, modele_rf_2])

# %%
# meme train/test que modele 1 pour comparer
modele_2 = pipeline_2.fit(train)
predictions_2 = modele_2.transform(test)
# Out:
# 26/07/21 22:23:53 WARN MemoryStore: Not enough space to cache rdd_361_12 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:53 WARN BlockManager: Persisting block rdd_361_12 to disk instead.
# 26/07/21 22:23:54 WARN MemoryStore: Not enough space to cache rdd_361_15 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:54 WARN BlockManager: Persisting block rdd_361_15 to disk instead.
# 26/07/21 22:23:54 WARN MemoryStore: Not enough space to cache rdd_361_5 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:54 WARN BlockManager: Persisting block rdd_361_5 to disk instead.
# 26/07/21 22:23:54 WARN MemoryStore: Not enough space to cache rdd_361_9 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:54 WARN BlockManager: Persisting block rdd_361_9 to disk instead.
# 26/07/21 22:23:54 WARN MemoryStore: Not enough space to cache rdd_361_4 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:54 WARN BlockManager: Persisting block rdd_361_4 to disk instead.
# 26/07/21 22:23:54 WARN MemoryStore: Not enough space to cache rdd_361_3 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:54 WARN BlockManager: Persisting block rdd_361_3 to disk instead.
# 26/07/21 22:23:54 WARN MemoryStore: Not enough space to cache rdd_361_0 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:54 WARN BlockManager: Persisting block rdd_361_0 to disk instead.
# 26/07/21 22:23:54 WARN MemoryStore: Not enough space to cache rdd_361_6 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:54 WARN BlockManager: Persisting block rdd_361_6 to disk instead.
# 26/07/21 22:23:54 WARN MemoryStore: Not enough space to cache rdd_361_13 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:54 WARN BlockManager: Persisting block rdd_361_13 to disk instead.
# 26/07/21 22:23:55 WARN MemoryStore: Not enough space to cache rdd_361_14 in memory! (computed 43.9 MiB so far)
# 26/07/21 22:23:55 WARN BlockManager: Persisting block rdd_361_14 to disk instead.
# 26/07/21 22:23:55 WARN MemoryStore: Not enough space to cache rdd_361_11 in memory! (computed 43.9 MiB so far)
# 26/07/21 22:23:55 WARN BlockManager: Persisting block rdd_361_11 to disk instead.
# 26/07/21 22:23:55 WARN MemoryStore: Not enough space to cache rdd_361_8 in memory! (computed 43.9 MiB so far)
# 26/07/21 22:23:55 WARN BlockManager: Persisting block rdd_361_8 to disk instead.
# 26/07/21 22:23:55 WARN MemoryStore: Not enough space to cache rdd_361_10 in memory! (computed 43.9 MiB so far)
# 26/07/21 22:23:55 WARN BlockManager: Persisting block rdd_361_10 to disk instead.
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_6 in memory! (computed 27.7 MiB so far)
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_3 in memory! (computed 5.5 MiB so far)
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_5 in memory! (computed 5.5 MiB so far)
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_15 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_14 in memory! (computed 27.7 MiB so far)
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_8 in memory! (computed 18.5 MiB so far)
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_12 in memory! (computed 3.5 MiB so far)
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_10 in memory! (computed 8.2 MiB so far)
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_13 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_4 in memory! (computed 1571.6 KiB so far)
# 26/07/21 22:23:59 WARN MemoryStore: Not enough space to cache rdd_361_11 in memory! (computed 43.9 MiB so far)
# 26/07/21 22:24:00 WARN MemoryStore: Not enough space to cache rdd_361_0 in memory! (computed 12.3 MiB so far)
# 26/07/21 22:24:03 WARN MemoryStore: Not enough space to cache rdd_361_16 in memory! (computed 27.7 MiB so far)
# 26/07/21 22:24:03 WARN BlockManager: Persisting block rdd_361_16 to disk instead.
# 26/07/21 22:24:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_6 in memory.
# 26/07/21 22:24:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_11 in memory.
# 26/07/21 22:24:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_12 in memory.
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_6 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_11 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_12 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_14 in memory.
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_14 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_13 in memory.
# 26/07/21 22:24:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_4 in memory.
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_13 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_4 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_10 in memory.
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_10 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_0 in memory.
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_0 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_15 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_3 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_5 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:05 WARN MemoryStore: Not enough space to cache rdd_361_8 in memory! (computed 1571.6 KiB so far)
# 26/07/21 22:24:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_3 in memory.
# 26/07/21 22:24:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_13 in memory.
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_3 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_13 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_6 in memory.
# 26/07/21 22:24:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_12 in memory.
# 26/07/21 22:24:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_0 in memory.
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_6 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_12 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_15 in memory.
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_0 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_15 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_11 in memory.
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_11 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_8 in memory.
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_8 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_5 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_14 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_10 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:09 WARN MemoryStore: Not enough space to cache rdd_361_4 in memory! (computed 1571.6 KiB so far)
# 26/07/21 22:24:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_8 in memory.
# 26/07/21 22:24:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_4 in memory.
# 26/07/21 22:24:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_15 in memory.
# 26/07/21 22:24:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_13 in memory.
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_15 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_4 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_13 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_8 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_11 in memory.
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_11 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_6 in memory.
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_6 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_0 in memory.
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_0 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_14 in memory.
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_14 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_12 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_5 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_10 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:14 WARN MemoryStore: Not enough space to cache rdd_361_3 in memory! (computed 1571.6 KiB so far)
# 26/07/21 22:24:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_0 in memory.
# 26/07/21 22:24:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_14 in memory.
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_0 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_15 in memory.
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_14 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_15 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_5 in memory.
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_5 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_11 in memory.
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_11 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_3 in memory.
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_3 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_4 in memory.
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_4 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_361_13 in memory.
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_13 in memory! (computed 504.0 B so far)
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_10 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_12 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_8 in memory! (computed 1046.8 KiB so far)
# 26/07/21 22:24:19 WARN MemoryStore: Not enough space to cache rdd_361_6 in memory! (computed 1571.6 KiB so far)
# [Stage 194:=============>                                         (4 + 12) / 16]

# %%
auc_2, recall_2, vp_2, fn_2, fp_2 = evaluer(predictions_2, "modele 2 (sans soldes)")
# Out:
# [Stage 225:===================================================>   (16 + 1) / 17]
# modele 2 (sans soldes)
# AUC       : 0.9302
# detectees : 199
# ratees    : 1480
# erreurs   : 14
# recall    : 11.9 %

# %%
# matrice de confusion
predictions_2.groupBy("isFraud", "prediction").count().orderBy("isFraud", "prediction").show()
# Out:
# [Stage 231:===================================================>   (16 + 1) / 17]
# +-------+----------+-------+
# |isFraud|prediction|  count|
# +-------+----------+-------+
# |      0|       0.0|1271418|
# |      0|       1.0|     14|
# |      1|       0.0|   1480|
# |      1|       1.0|    199|
# +-------+----------+-------+

# %%
# sur quoi le modele 2 se base
rf_2 = modele_2.stages[-1]
imp_2 = rf_2.featureImportances

for nom, score in zip(col_sans_soldes, imp_2):
    print(nom, ":", round(float(score), 4))

noms = []
vals = []
for i in range(len(col_sans_soldes)):
    noms.append(col_sans_soldes[i])
    vals.append(float(imp_2[i]))

plt.figure(figsize=(8, 4))
plt.barh(noms, vals, color="orange")
plt.title("modele 2 : importance des variables")
plt.xlabel("importance")
plt.tight_layout()
plt.show()
# Out:
# step : 0.5663
# type_num : 0.2829
# amount : 0.1506
# typeEchange_num : 0.0001

# %% [markdown]
# ---
# # 5 : comparaison
#
# les 2 modeles + le systeme de la banque

# %%
print("            modele 1     modele 2")
print("AUC        ", round(auc_1, 4), "     ", round(auc_2, 4))
print("recall      ", round(100*recall_1, 1), "%      ", round(100*recall_2, 1), "%")
print("detectees  ", vp_1, "        ", vp_2)
print("ratees      ", fn_1, "        ", fn_2)
print("erreurs    ", fp_1, "          ", fp_2)
# Out:
#             modele 1     modele 2
# AUC         0.989       0.9302
# recall       47.9 %       11.9 %
# detectees   804          199
# ratees       875          1480
# erreurs     0            14

# %%
#  AUC
plt.figure(figsize=(6, 4))
plt.bar(["modele 1\n(avec soldes)", "modele 2\n(sans soldes)"], [auc_1, auc_2],
        color=["teal", "orange"])
plt.title("comparaison des AUC")
plt.ylabel("AUC")
plt.ylim(0, 1)
plt.show()

# %%
#recall (+ banque)
recall_banque = fraudes_oui / totalF

plt.figure(figsize=(7, 4))
plt.bar(["banque", "modele 1\n(avec soldes)", "modele 2\n(sans soldes)"],
        [100*recall_banque, 100*recall_1, 100*recall_2],
        color=["gray", "teal", "orange"])
plt.title("% de fraudes detectees")
plt.ylabel("recall (%)")
plt.show()

# %% [markdown]
# ---
# ## Conclusion
#
# 1 le systeme de la banque detecte presque rien => il fallait autre chose
#
# 2 la fraude a une signature nette : TRANSFER/CASH_OUT, entre particuliers (CC), gros montants
#
# 3 le modele 1 (AUC 0.98) se base a ~70% sur les soldes = colonnes interdites par la doc
# => fuite de donnees, le score est un mirage
#
# 4 le modele 2 sans ces colonnes est plus honnete : scores plus bas mais realistes
#
#
# ### limites
#
# - dataset desequilibre (0.13% de fraudes) => l'accuracy est trompeuse, on regarde le recall
# - pour ameliorer le recall : rééquilibrer les classes ou ajuster le seuil

# %% [markdown]
# ## Fin : liberer ressources

# %%
spark.stop()
